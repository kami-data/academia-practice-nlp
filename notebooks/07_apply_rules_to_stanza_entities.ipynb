# %% [markdown]
# # Academia–Practice Interaction Mapping Using NLP
# **Notebook 07:Apply Rules to Stanza-Only Entities**
#
# **Author:** Kamila Lewandowska
# **Project Phase:** In Progress
# **Last Updated:** June 2025
#
# ---
#
# ## Objective
#
# Apply the rule-based classification logic developed on the manually annotated *common entities* dataset to the remaining *Stanza-only* entities. This helps extend the categorization of non-academic organizations beyond the initial overlap with spaCy/transformer models.
#
# ---
#
# ## Workflow Summary
#
# - Load raw Stanza output (`ner_stanza_pl.csv`) and filter out already classified entities
# - Preprocess the remaining Stanza-only entities:
#   - Clean and normalize organization names
#   - Remove likely academic entities using a keyword-based filter
#   - Lemmatize names for more robust matching
# - Apply rule-based classification using pre-defined keyword lists (from Notebook 05)
# - Split into rule-matched and unmatched groups for further inspection
#
# ---
#
# ## Rule-Based Categorization
#
# - A dictionary of lemmatized keywords was used to match organizations to one of 11 categories:
#
# ---
#
# ## Key Outcomes
#
# - **Stanza-only non-academic entities after cleaning:** *12490*
# - **Classified by rules:** *[insert number]*
# - **Remaining unmatched (“Other / Unclear”):** *[insert number]*

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import re
import stanza
from collections import Counter

# %% [markdown]
# # Data preparation and preprocessing

# %% [markdown]
# ## Create stanza_only dataset

# %%
# Isolate Stanza-Only Entities

# Load full Stanza output
df_stanza_all = pd.read_csv("../output/ner_stanza_pl.csv")  
df_common = pd.read_csv("../output/common_org_entities.csv")

# %%
df_stanza_all.head(5)
# Out:
#                                                 Text  \
# 0  Badania skupiające się na szczegółowej analizi...
# 1  Birdwatching, czyli obserwacje w terenie ptakó...
# 2  Efektywny transfer wiedzy jest podstawowym czy...
# 3  Ważnym obszarem działalności naukowej WSPiA je...
# 4  Znaczna część europejskiego dziedzictwa archeo...
#
#                                  ORG_Entities_stanza  \
# 0  ['Komitetu Nauk Weterynaryjnych i Rozrodu Zwie...
# 1  ['Królewskie Towarzystwo Ochrony Ptaków', 'Fac...
# 2                              ['MŚP', 'MŚP', 'ETW']
# 3  ['WSPiA', 'AP', 'WSPiA', '4 Zespoły', 'AP', 'A...
# 4  ['Interreg Central Europe', 'Archaeological He...
#
#                                  ICS_ID
# 0  00153fbd-82f7-48c4-b5bd-e830bc390244
# 1  002768f1-8b96-4e0f-bcc8-192eb0594e60
# 2  00500483-f00c-4410-b6f7-8650a003125f
# 3  006e7fef-2083-426d-9c1b-1affd27b939e
# 4  00901439-d91a-48e0-903a-26a4253c3a0c

# %%
# Check the type of data of the row with entities

type(df_stanza_all["ORG_Entities_stanza"].iloc[0])
# Out:
# str

# %%
# Extract unique ORG entities from df_stanza_all

# Flatten all (ICS_ID, ORG_Entity) pairs from Stanza

# List to hold flattened records

all_stanza_entities = []

# Loop through each row in stanza data
for _, row in df_stanza_all.iterrows():
    ics_id = row["ICS_ID"]
    try:
        org_list = literal_eval(row["ORG_Entities_stanza"])
        for org in org_list:
            org_cleaned = org.strip()
            if isinstance(org_cleaned, str) and org_cleaned:
                all_stanza_entities.append((ics_id, org_cleaned))
    except:
        continue

# Create dataframe
all_stanza_flat = pd.DataFrame(all_stanza_entities, columns=["ICS_ID", "ORG_Entity"])

# %%
all_stanza_flat.head(20)
# Out:
#                                   ICS_ID  \
# 0   00153fbd-82f7-48c4-b5bd-e830bc390244
# 1   00153fbd-82f7-48c4-b5bd-e830bc390244
# 2   00153fbd-82f7-48c4-b5bd-e830bc390244
# 3   00153fbd-82f7-48c4-b5bd-e830bc390244
# 4   00153fbd-82f7-48c4-b5bd-e830bc390244
# 5   00153fbd-82f7-48c4-b5bd-e830bc390244
# 6   00153fbd-82f7-48c4-b5bd-e830bc390244
# 7   00153fbd-82f7-48c4-b5bd-e830bc390244
# 8   00153fbd-82f7-48c4-b5bd-e830bc390244
# 9   00153fbd-82f7-48c4-b5bd-e830bc390244
# 10  00153fbd-82f7-48c4-b5bd-e830bc390244
# 11  00153fbd-82f7-48c4-b5bd-e830bc390244
# 12  00153fbd-82f7-48c4-b5bd-e830bc390244
# 13  00153fbd-82f7-48c4-b5bd-e830bc390244
# 14  00153fbd-82f7-48c4-b5bd-e830bc390244
# 15  002768f1-8b96-4e0f-bcc8-192eb0594e60
# 16  002768f1-8b96-4e0f-bcc8-192eb0594e60
# 17  002768f1-8b96-4e0f-bcc8-192eb0594e60
# 18  002768f1-8b96-4e0f-bcc8-192eb0594e60
# 19  002768f1-8b96-4e0f-bcc8-192eb0594e60
#
#                                            ORG_Entity
# 0   Komitetu Nauk Weterynaryjnych i Rozrodu Zwierz...
# 1                                      Rady Doradczej
# 2                                      Advisory Board
# 3                              Medycyna Weterynaryjna
# 4                         Journal of Applied Genetics
# 5                                            SPRINGER
# 6                                                Gene
# 7                                            ELSEVIER
# 8                                  Scientific Reports
# 9                                             Zespołu
# 10                                            Katedry
# 11                                           Facebook
# 12                                            Katedrę
# 13                                        Uniwersytet
# 14                                        Uniwersytet
# 15              Królewskie Towarzystwo Ochrony Ptaków
# 16    Facebook Zakładu Biologii i Ekologii Ptaków UAM
# 17                                                UAM
# 18                 Stowarzyszenie „Grupa EkoLogiczna”
# 19                                                UAM

# %%
# Filter out entities that were already processed (the 6111 “common”)

# Set of already classified entities
common_entities_set = set(df_common['ORG_Entity'].str.strip())

# Keep only stanza-only entries
df_stanza_only = all_stanza_flat[~all_stanza_flat["ORG_Entity"].isin(common_entities_set)].copy()

# Check number of unique entities and entries
print("Unique entities:", df_stanza_only["ORG_Entity"].nunique())
print("Total rows:", len(df_stanza_only))
# Out:
# Unique entities: 11877
# Total rows: 15092

# %%
# Convert to DataFrame and save

df_stanza_only.to_csv("../output/stanza_only_entities.csv", index=False)

# %% [markdown]
# ## Preprocess stanza_only: STEP 1 Basic cleaning

# %%
# Function for basic claening: whitespace, removinh redundant entries

def clean_entity(entity):
    if not isinstance(entity, str):       # Check if the input is a string; if not, return None
        return None
    entity = re.sub(r'\s+', ' ', entity).strip()    # Replace multiple whitespace characters with a single space and trim leading/trailing spaces
    entity = re.sub(r'^[^\w]+', '', entity)         # Remove any non-word characters from the beginning of the string
    entity = re.sub(r'[^\w.]+$', '', entity)        # Remove any non-word characters (excluding period) from the end of the string
    return entity if len(entity) >= 3 else None      # Return the cleaned entity if it has at least 3 characters; otherwise, return None

# %%
# Apply the clean_entity function

df_stanza_only["Cleaned_Entity"] = df_stanza_only["ORG_Entity"].apply(clean_entity)
stanza_only_cleaned = df_stanza_only.dropna(subset=["Cleaned_Entity"]).reset_index(drop=True)
print(f"After cleaning: {len(stanza_only_cleaned)} rows.")
# Out:
# After cleaning: 14893 rows.

# %% [markdown]
# ## Preprocess stanza_only: STEP 2 Rule-based academic entity removal

# %%
# Load academic keyword list (copied from notebook 04)

academic_keywords = [
    'instytut', 'pan', 'university', 'nauk', 'uniwersytet', 'wydział', 'wydzial', 'department', 'badań', 'akadem', 
    'katedr', 'politechni', 'laboratorium', 'research', 'institut', 'fizy', 'matematy', 
    'architektur', 'pracown', 'pedagogi', 'filozof', 'medycyn', 'medyczn', 'medical', 'językoznawstwo', 
    'mickiewicz', 'biolog', 'studia', 'uczeln', 'kolegium', 'collegium', 'studium', 'colleg', 'universit', 
    'wyższ', 'journal', 'springer', 'doktor']

# %%
# Lowercase for rule-based match

stanza_only_cleaned["entity_lower"] = stanza_only_cleaned["Cleaned_Entity"].str.lower()

# %%
# Remove academic entities

stanza_only_cleaned["Is_Academic"] = stanza_only_cleaned["entity_lower"].apply(lambda x: any(kw in x for kw in academic_keywords))
stanza_only_non_academic = stanza_only_cleaned[~stanza_only_cleaned["Is_Academic"]].copy().reset_index(drop=True)
print(f"After removing academic entities: {len(stanza_only_non_academic)} rows.")
# Out:
# After removing academic entities: 12490 rows.

# %% [markdown]
# # Rule-based Classification

# %%
# Download and initialize Stanza for Polish

stanza.download("pl")
nlp = stanza.Pipeline(lang="pl", processors="tokenize,mwt,lemma")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-06-24 15:34:15 INFO: Downloaded file to C:\Users\lewandowska\stanza_resources\resources.json
# 2025-06-24 15:34:15 INFO: Downloading default packages for language: pl (Polish) ...
# 2025-06-24 15:34:16 INFO: File exists: C:\Users\lewandowska\stanza_resources\pl\default.zip
# 2025-06-24 15:34:18 INFO: Finished downloading models and saved to C:\Users\lewandowska\stanza_resources
# 2025-06-24 15:34:18 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-06-24 15:34:18 INFO: Downloaded file to C:\Users\lewandowska\stanza_resources\resources.json
# 2025-06-24 15:34:18 INFO: Loading these models for language: pl (Polish):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | pdb          |
# | mwt       | pdb          |
# | lemma     | pdb_nocharlm |
# ============================
#
# 2025-06-24 15:34:18 INFO: Using device: cpu
# 2025-06-24 15:34:18 INFO: Loading: tokenize
# 2025-06-24 15:34:19 INFO: Loading: mwt
# 2025-06-24 15:34:19 INFO: Loading: lemma
# 2025-06-24 15:34:20 INFO: Done loading processors!

# %%
# Function to lemmatize entities

def lemmatize_entity(text):
    doc = nlp(text)
    lemmas = [word.lemma for sent in doc.sentences for word in sent.words]
    return " ".join(lemmas)

# %%
# Apply lemmatize entities function

stanza_only_non_academic["Lemma_Entity"] = stanza_only_non_academic["Cleaned_Entity"].apply(lemmatize_entity)

# %%
# Fix incorrect lemmatizations (from notebook 05)

lemma_fixes = {
    "do_tar": "DG",
    "sa .": "s.a.",
    "s.a .": "s.a.",
    "o.o": "o.o.",
    "z ograniczona_odpowiedzialność .": "z o.o.",
    "z ograniczona_odpowiedzialność": "z o.o.",
    "do_spraw .": "ds.",
    "te_jeta_bowy": "TV",
    "roktóry": "rp",
    "et_yg_pały": "ETW",
    "to_sysapipiporoby": "TVP",
    "lt_yp_dwownokinoć": "Ltd",
    "fektometr_pici": "FM",
}

# Apply the correction

def apply_fixes(text):
    for wrong, correct in lemma_fixes.items():
        text = text.replace(wrong, correct)
    return text

stanza_only_non_academic["Lemma_Cleaned"] = stanza_only_non_academic["Lemma_Entity"].apply(apply_fixes)

# %%
# Ruled based keyword dictionary (from notebook 05 and enhanced manually after reviewing unmached entities)

lemmatized_keywords_by_category_clean = {
       "Government / Public Administration": [
        "urząd", "ministerstwo", "gmina", "powiat", "rada", "sejm", "senat",
        "województwo", "rp", "komisja", "samorząd", "narodowy", "krajowy", "izba",
        "państwowy", "miasto", "regionalny", "województwo", "wojewódzki", "marszałkowski",
        "sąd", "inspektorat", "parlament", "rzeczpospolita", "agencja", "państwowy", "stołeczny", "stołeczne", "ambasada",
        "rzecznik", "senacko", "inspekcja", "inspekcję", "inspektor", "konsula", "turystyczna", "turystyczny", "delegatura",
        "punkt", "fundusz", "skarb", "rząd", "dyrekcja", "archiwum"
    ],
     "NGO / Association / Foundation": [
        "fundacja", "fundacją", "stowarzyszenie", "towarzystwo", "zrzeszenie", "federacja", "koalicja", "association", "związek", "obywatelski",
         "wspólota", "pomoc"
    ],
   
    "Media / Publishing": [
        "radio", "tv", "gazeta", "media", "wydawnictwo", "czasopismo", "prasa", "tvp", "fm"
    ],
    "Cultural Institution / Arts": [
        "muzeum", "teatr", "galeria", "festiwal", "filharmonia", "dom", "kultura", "sztuka", "artystyczny", "artystyczne",
        "twórczość", "książka", "muzyczny", "museum", "koncert", "zamek", "królewski", "pałac", "klub", "filmowy",
        "heritage"
    ],
    "Health / Hospitals / Medical": [
        "zdrowia", "zdrowie", "klinika", "szpital", "lekarz", "medyczny", "przychodnia", "sanatorium", "rehabilitacja", "zdrowiu", "zdrowotny"
        "hospicjum", "choroba", "epidemia", "health", "uzdrowisko", "sanatorium", "chory"
    ],
    "Religious Organization": [
        "kościół", "parafia", "diecezja", "episkopat", "zakon", "misja", "cerkiew", "salwatorianie", "salwatorian", "duchowa", "biblijny", "biblijnym", "kuria",
        "metropolita", "parafia", "parafię"
    ],
    "Military / Defense / Security": [
        "wojsko", "żandarmeria", "bezpieczeństwo", "policja", "straż", "obrona", "militaria", "komendant", "lotniczy", "lotniczej", "policję", "zbrojny"
    ],
    "International Organization / EU": [
        "europejski", "unia", "ue", "nato", "unesco", "oecd", "who", "międzynarodowy", "international", "european", "DG", "union", "dyrektoriat", "nations"
    ],
    "Company / Business": [
       "s.a.", "s.a", "z o.o.", "holding", "firma", "grupa", "przedsiębiorstwo",
        "technologia", "logistyka", "consulting", "solutions", "commerce", "industry", "group", "spółka", "Ltd", "stocznia", "kopalni", "firmą", "huta"
    ],
       
    "Education (non-university)": [
        "liceum", "technikum", "szkoła", "podstawowy", "przedszkole", "edukacja", "biblioteka", "bibliotek", "szkolenie", "nauczyciel", "podyplomowy",
        "oświatowy", "oświata", "kurator", "kuratorium", "szkolno", "szkolny", "przedszkolny"
    ],
    "Other / Unclear": []  # fallback category
}

# %%
# Define a function to match a lemmatized entity against category keyword lists

def match_entity_to_category(entity, keyword_dict):
    """
    Matches a lemmatized entity string to one of the predefined categories
    based on the presence of any lemmatized keywords.

    Parameters:
        entity (str): The lemmatized name of an organization.
        keyword_dict (dict): Dictionary mapping category names to keyword lists.

    Returns:
        str: The matched category name, or "Other / Unclear" if no match found.
    """
    entity_lower = entity.lower()
    for category, keywords in keyword_dict.items():
        if any(keyword in entity_lower for keyword in keywords):
            return category
    return "Other / Unclear"

# %%
# Apply the match_entity_to_category function

stanza_only_non_academic["Matched_Category"] = stanza_only_non_academic["Lemma_Cleaned"].apply(lambda x: match_entity_to_category(x, lemmatized_keywords_by_category_clean))

# %%
# Split: rule-matched and unmatched

stanza_non_academic_rule_matched = stanza_only_non_academic[stanza_only_non_academic["Matched_Category"] != "Other / Unclear"].copy()
stanza_non_academic_unmatched = stanza_only_non_academic[stanza_only_non_academic["Matched_Category"] == "Other / Unclear"].copy()

print(f"Rule-matched: {len(stanza_non_academic_rule_matched)} rows.")
print(f"Unmatched {len(stanza_non_academic_unmatched)} rows.")
# Out:
# Rule-matched: 4549 rows.
# Unmatched 7941 rows.

# %%
print(stanza_non_academic_rule_matched["ORG_Entity"].nunique())
print(stanza_non_academic_unmatched["ORG_Entity"].nunique())
# Out:
# 3821
# 5849

# %%
# Inspect the data: check frequencies of categories

cat_freq = Counter(stanza_non_academic_rule_matched["Matched_Category"])
cat_freq
# Out:
# Counter({'Government / Public Administration': 1733,
#          'Company / Business': 657,
#          'Cultural Institution / Arts': 537,
#          'NGO / Association / Foundation': 495,
#          'International Organization / EU': 383,
#          'Education (non-university)': 237,
#          'Media / Publishing': 198,
#          'Health / Hospitals / Medical': 174,
#          'Military / Defense / Security': 76,
#          'Religious Organization': 59})

# %%
set(stanza_non_academic_unmatched["Lemma_Cleaned"])
# Out:
# {'belorus',
#  'kuow',
#  'prodrobota',
#  'sgppl „ dolina lotnicza',
#  'FAPPS',
#  'on- 1',
#  'nestle',
#  'mrk_hpam',
#  'mza',
#  'info',
#  'hnms',
#  'dolar_ameryłsza',
#  'Słttip',
#  'Schneider Polska',
#  'nike',
#  'frontiers forówna Young minds',
#  'müller',
#  'sędzia2',
#  'Zagroda podlaski',
#  'glinojeck',
#  'kafu',
#  'newg lab pharma',
#  'kuźnia pomysłów',
#  'pRL-u',
#  'krakowskie chorągwi ZHP',
#  'zespół badanie',
#  "l'oreal",
#  'msatjo Manggha',
#  'cogInfoCom',
#  'stacja badawcza',
#  'supramak',
#  'shadowing',
#  'kaszubski UL',
#  'Ir_A',
#  'uniwersytet w Edynburg',
#  'sk-cz',
#  'litgrid',
#  'IX gremium ekspert turystyka',
#  'kongres',
#  'centrum informacja i promocja śródlądowy droga wodny w Bydgoszcz',
#  'associação para',
#  'tow . przyjaciel sulejówka',
#  'apeva',
#  'giorin',
#  'angielski . science inny poland',
#  'górnictwo i energetyka agś',
#  'we',
#  'strategia dunajska',
#  'JSA',
#  'thyssenkrupp',
#  'gdańską',
#  'K . chty',
#  'social affairs and inclusion',
#  'kaplast',
#  'trace',
#  'jada',
#  'Z. wałęgi',
#  'spebeI flow',
#  'hed KMS',
#  'geoteko',
#  'grupo kruk',
#  'lead',
#  'ipcera',
#  'IZK',
#  'michelin Polska',
#  'organizator społeczność lokalny',
#  'lider',
#  'mEaTqualit',
#  'formação',
#  'arbeitsstelle holocaustliteratur',
#  'alior bank',
#  'med silesia',
#  'coface',
#  'atypia',
#  'pasieka',
#  'khairagarh',
#  'asesora',
#  'zespół problemowy Wrdskusczy woj . łódzki ds. transformacja region bełchatowski',
#  'danish Road directoriate',
#  'wfosigw',
#  'ikev2',
#  'auli',
#  'ince',
#  'horównam',
#  'vision express',
#  'bea-app',
#  'usenix',
#  'malko_eca',
#  'jeothi seva schools',
#  'sagrera',
#  'ernst & Young',
#  'ptwk',
#  'wpsa',
#  'sarster',
#  'Igran_pa',
#  'tyski klaster energia',
#  'corym_pałtorab',
#  'ośrodek brama grodzka',
#  'FOB',
#  'sartorius',
#  'JM rektor UG',
#  'UOKiK',
#  'toroidy.pl',
#  'zetcjaczy',
#  'olkuski',
#  'medch',
#  'KH keeper',
#  'iocny_intobicja_Rybołówła świerad',
#  'lexus żerań',
#  'erknet',
#  'PW niepodległa',
#  'sukilelie',
#  'ECCP',
#  'waste klaster',
#  'shippóon',
#  'podkis',
#  'DNA',
#  'rochester',
#  'zmroza',
#  'WFIS',
#  'strategic advisor board of the Quantum Technology flagship',
#  'jednostka specjalny żandarmerii wójsko',
#  'silicon creation',
#  'boguchwała smart City',
#  'Google analitics',
#  'famot',
#  'expo horticultural 2029',
#  'living lab',
#  'httr',
#  'mico',
#  'pyromagazin',
#  'toe',
#  'carmen',
#  'getback SA',
#  'obserwatorium astronomiczno - geodezyjny PW',
#  'artykuł celebration',
#  'eortc',
#  'brygadźie wsparcia dowodzenie',
#  'Nas',
#  'TDT',
#  'grimaldi SA',
#  'eduball',
#  'ring sport',
#  'viba.pl',
#  'intosai',
#  'bydgoski dolina narzędziowa',
#  'prevac',
#  'zakładem wodociąg i kanalizacja',
#  'DHI Polska',
#  'oddziału krakowski PTF',
#  'krory_oca',
#  'pliva',
#  'WNo KA',
#  'volvo',
#  'trzygłów',
#  'fonterra',
#  'sars-cov- 2',
#  'smrt.bio',
#  'małopolski program ochrona',
#  'Qlook',
#  'departament wschodnie MSZ',
#  'podkomitet ds. asfaltów KT 222 PkN',
#  'algaelabs',
#  'eostat',
#  'zakład ubezpieczenie zdrowotny',
#  'Na_tymucza',
#  'GFK Polonia',
#  'ten',
#  'dydaktyki i popularyzacji astronomii „ planetarium',
#  'aotmite',
#  'JKI',
#  'krapfa',
#  'meub',
#  'plan agropecuario',
#  'regionWeek',
#  'SK nowy jankowice',
#  'fondation',
#  'martrow',
#  'edx.org',
#  'inżynierii środowisko , górnictwo i energetyka',
#  'fend',
#  'uniw . stavanger',
#  'meet hydrogen',
#  'Ijtym_połorcadra_dabołówba',
#  'fokstrot',
#  'DK około',
#  'airbus',
#  'top management teams',
#  'monnari',
#  'praca socjalna',
#  'klinice',
#  'szlachetna paczka',
#  'peridea Barbara łączny',
#  'COsT',
#  'fomo',
#  'pisa',
#  'Ukraina',
#  'verarbeiten',
#  'genmarka',
#  'amiga info point',
#  'mit press',
#  'pochp',
#  'młeś',
#  'WISS wadrzeszeńce inżynieria samochodów specjalny wiss.com.pl „ wawrzaszek inżynieria samochodów specjalny',
#  'hospicjum',
#  'nod',
#  'shtBałtyk',
#  'europepski obserwator audiowizua',
#  'viba',
#  'zespół iitd „ neolek',
#  'SFD meka',
#  'indigenous',
#  'wipasz',
#  'konwencja berneńska ds. Igo',
#  'uniwersytet w utrechcie',
#  'zespół doraźnego ds.',
#  'Oxford academics',
#  'deutche welle',
#  'SKN supramak',
#  'central laboratory',
#  'motet wünschet jerusal glück',
#  'gwsh',
#  'uniwersytet w Luksemburg',
#  'snna',
#  'aszwoj',
#  'mathematische studiengesellschaft gmba',
#  'ZOO',
#  'dctk w Wrocław',
#  'Ca_',
#  'brugg',
#  'gameit',
#  'zuo Krosno',
#  'instytut obserwatorium astronomiczne gam',
#  'zakładem mięsnomię „ jasiołka',
#  'dual energy energy intym_podobdab .',
#  'alaf poland',
#  'marania',
#  'VeraP',
#  'PIG -PIB',
#  'knowo Sgga',
#  'mla Brazylia',
#  'PPE',
#  'meteoswiss',
#  'KBC',
#  'norwegian environment agency',
#  'German marshall fund',
#  'KRUS',
#  'arakis-gov',
#  'esaler',
#  'phönix Europa e.V',
#  'nucair technologies',
#  'nanorevit',
#  'Nak',
#  'kongskilde maskinfabrik',
#  'komitet ds. oceny ryzyko',
#  'szwajcaria',
#  'BWA Olsztyn',
#  'HEG',
#  'instytut dizajno w Kielce',
#  'aasa',
#  'bremer',
#  'pbgot',
#  'bickenb',
#  'sanofi - aventis',
#  'IJ ujtym_podobdodceza',
#  'nacterc',
#  'enmkiob',
#  'stowarzyszyć nowoczesne budynki',
#  'ultragen',
#  'unitar',
#  'mz',
#  'PTNP',
#  'redesigning equality and scientific excellence together',
#  'KRS 0000652156',
#  'Tili',
#  'Canadian broadcasting',
#  'esttypopinie',
#  'sylva',
#  'seal of excellence',
#  'eg_m',
#  'lora alliance',
#  'nciad',
#  'centrum inteligentny rozwój',
#  'msctn siedlce',
#  'saama technologies intym_podobdab',
#  'TMG',
#  'STI Szwecja',
#  'Zost_picza marmat',
#  'gospodarstwo rolno - rybackim w ławka',
#  'zakład produkcyjny purella',
#  'DG agri',
#  'andropol SA',
#  'perła warmię',
#  'orteh',
#  'm_ptpwa - N',
#  'Eas',
#  'sojusznicze dowództwo ds. transformacja z norfolk',
#  'wspólnica sp.k .',
#  'siecią',
#  'uniwersytet Witold wielki w kowno',
#  'american Elements',
#  'departament rynek praca',
#  'streetworking',
#  'prswdzecpadyje',
#  'suzlon energy limited india',
#  'jakipreS',
#  '1itąk polish Yeast conference',
#  'instytut historia UJK',
#  'cosme',
#  'capd',
#  'camino polaco',
#  'odrów',
#  'EQlspus_',
#  'komitet doradczy',
#  'business Development agency',
#  'vives univesit',
#  'eapny Polska',
#  'energa_oper oddział',
#  'erąk_pactora ipczd',
#  'bet gmba',
#  'rapoport',
#  'nordkalk',
#  'dezosan',
#  'kiztpl',
#  'centrum aktywność społeczny w Białystok',
#  'wydo . wolters kluwer',
#  'kuldeteknisk AS',
#  'awas',
#  'wspólnota',
#  'travel chanel poland',
#  'ECM records',
#  'ce',
#  'CM dmk',
#  'SZe',
#  'ina',
#  'pontifica universidad catolica del ecuador',
#  'fireke',
#  'shanghai supercarbon graphene',
#  'Europa',
#  'borimex',
#  'rad biznes',
#  'TU chemnitz',
#  'geoheatpol',
#  'synthia',
#  'pałył_pa',
#  'rarescreen',
#  'town centre management',
#  'mew L . kotarski',
#  'gospostrateg -htrzycpatorcza',
#  'lubawa S . a',
#  'Brak',
#  'wimic agś',
#  'B SPZOZ',
#  'ośrodek badawczo - rozwojowy',
#  'hong kong',
#  'zespół wbihz',
#  'exmot',
#  'instytut informatyka UP',
#  'opS-y',
#  'universidad catolica del norte',
#  'mgmt',
#  'soft-clil',
#  'zgibiś',
#  'arkema',
#  'seldon',
#  'nefpy_ocin',
#  'protysuł praski',
#  'pl-cz',
#  'eelco fiole - managing',
#  'gcos',
#  'KIL upoł_',
#  'cot-ów',
#  'piktime',
#  'InS UR',
#  'SPJP',
#  'Intel',
#  'e__em_pik',
#  'banco daycoval',
#  'flsmidth',
#  'creotech',
#  'ekolaura polskiej izian ekologise',
#  'trauma',
#  'IPGDS',
#  'mebel BOS RU',
#  'ita',
#  'CE IPN',
#  'stomoz',
#  'rheinmetall waff muntion gmba',
#  'geo',
#  'KSOP',
#  'opole',
#  'zakład genetyki kliniczna Ced UM',
#  'WCh UŁ',
#  'pentor',
#  'KCHZ',
#  'fobran',
#  'optocap',
#  'multin',
#  'parceiro',
#  'bridgeAlph',
#  'posithot',
#  'lego',
#  'służbę geologiczna USA',
#  'innovative social investment',
#  'slag om grolle',
#  'strategia na rzecz odpowiedzialny rozwój',
#  'ipeg',
#  'ncy maestro',
#  'rad',
#  'doradztwo i projektowanie',
#  'Zrzeszenia kaszubsko - pomorski',
#  'scottsville',
#  'siecią badawczą łukasiewicz',
#  'mobilnej pielęgniarce " Mielec',
#  'r&d/qc',
#  'chino',
#  'jpjo',
#  'polski fadnd',
#  'WE pcz',
#  'directorate',
#  'mcdonald',
#  'centrum doradztwo rolniczy w brwinowie',
#  'EMBL',
#  'aiut',
#  'bty cottbus - senftenberg',
#  'National ambient air Quality conference',
#  'AcK cyfronet agś',
#  'russian planty Quarantine center',
#  'syriusz',
#  'ośrodek przygotowań olimpijski',
#  'rfssw',
#  'zachęty lubusko',
#  'agcen',
#  'mesekP',
#  'newsmapper',
#  'zespół WP6 SUM poland',
#  'hina',
#  'radmor',
#  'centre pompidou',
#  'eionet',
#  'nahua',
#  'Polska Zachodni',
#  'sopemi',
#  'rajpol',
#  'zakład bumar - łabęda',
#  'WS ujtym_podobdodceza',
#  'iura',
#  'gwzo',
#  'alaf',
#  'pomorzanin',
#  'dział techniczny mostostal Puławy',
#  'zgjędnicza tos',
#  'Polska klasyfikacja działalności',
#  'helch',
#  'circuse',
#  'vattenfall energy trading gmba',
#  'ekomis',
#  'cus-ów',
#  'Skost_am',
#  'teagasc',
#  'missolunghi',
#  'globecore',
#  'zSu',
#  'consultazione carismatica italiana',
#  'autmon',
#  'projekt dla środowisko',
#  'inter-iot',
#  'studio mtspas',
#  'PPN',
#  'burntec',
#  'LPP',
#  'hbsc',
#  'oddział w Rzeszów',
#  'uSz',
#  'auchania',
#  'oddziały GDDKiA',
#  'DAR STAL',
#  'prorew',
#  'aRtiTude',
#  'npwt',
#  'WWSse',
#  'koalicję na rzecz rozwój obrót bezgotówkowy i mikropłatność',
#  'biolab',
#  'power',
#  'oczyszczalnia Ścieków warta SA',
#  'tempmeko',
#  'lneg',
#  'mtsu center forówna historic preservation',
#  'vertigo s+t+arts',
#  'młtrz',
#  'M . benhochra',
#  'DG employment',
#  'SOS',
#  'telewizją Republika',
#  'KSWIM',
#  'santadner',
#  'UNFCCC',
#  'oddziałów GDDKiA',
#  'spin-off',
#  'soils2sea',
#  'WoS',
#  'KSC forum',
#  'szyb Poniatowski',
#  'stal',
#  'm_a . rosen',
#  'centrum badanie paliwod_pie , cieczy robocze i ochrona środowisko',
#  'GSR',
#  'polskij kulturnyj centr',
#  'polski marki turystyczne',
#  'uniwersytet w sydney',
#  'morski energetyka odnawialna',
#  'tsniesko',
#  'fasttext',
#  'deutsches zentrum fod_wnaw',
#  'ośr . rozw . pol . eduk . za granicą',
#  'next generation ey',
#  'światowy kongres chłodnictwo',
#  'wageningen',
#  'poczta Polska',
#  'global initiative',
#  'piasa',
#  'minamaty',
#  'poland prizo',
#  'sse-7',
#  'oculomedica',
#  'ośrodek zarybieniowy i wylęgarnia ryb łososiowaty',
#  'teb',
#  'brikol',
#  'twsft',
#  'member at large',
#  'woś',
#  'CBL',
#  'omaha',
#  'mastersport',
#  'ułano poznański',
#  'Vinci',
#  'KT PkN',
#  'KIC inno - energy',
#  'tw-on',
#  'wojewodę pomorski',
#  'Germania slavica vod . Polonia ruthenica',
#  'komitet ds. dialogu z judaizm',
#  'mebelbos UA',
#  'San Jose',
#  'encyklopedia administracja publiczna',
#  'arsynuł electronica',
#  'gazfistet',
#  'remea',
#  'eu-xfel',
#  'lab',
#  'centrum zdrowego życie w Norwegia',
#  'society',
#  'pomeranie',
#  'Cerzy_łocent UŚ',
#  'prorektor',
#  'polski norma',
#  'komenda garnizon Poznań',
#  'stopnia wodny siarzewo',
#  'prros',
#  'oddział okręgowy w gorzowie wielkopolski',
#  'verformen',
#  'pontificia universidad católica del ecuador',
#  'nno ’som',
#  'banco de Chile',
#  'departament informacja i promocja',
#  'selfrag',
#  'amn',
#  'terytorialna służba wójsko',
#  'lotos petrobaltic',
#  'państwo polski',
#  'urzęd rejestracja produkt leczniczy',
#  'trójmorze',
#  'mesko S .a . biuro technika rakietowy',
#  'Joint programming initiative',
#  'ośrodek iwrt',
#  'unita',
#  'H . cegielski',
#  'lapwood',
#  'Nasterciczy',
#  'eurocovcat',
#  'Google scholar',
#  'terminology',
#  'elektrowni opole',
#  'toyoty',
#  'hortus deliciarum',
#  'dukla',
#  'SFW-1 sanok',
#  'astronomii',
#  'PWR',
#  'elsevier Li_typtap .',
#  'sustainable Development goals',
#  'herrenhof mussba',
#  'think- tank',
#  'bafasal',
#  'mastere',
#  'ngos',
#  'pułko ułan poznański',
#  'top 10 polish talents',
#  'protech',
#  'oka',
#  'kołorking',
#  'china',
#  'kolaj magazine',
#  'eurokodów',
#  'asos',
#  'komitet główny olijp',
#  'źar',
#  'stow . plantator miniKi',
#  'prokuratura integracja społeczny',
#  'cleantech south baltic',
#  'oafpy',
#  'PZU',
#  'edihów',
#  'sto',
#  'sentimenti',
#  'synod',
#  'ECB',
#  'II SAK',
#  'departament sprawa społeczny UM Wrocław',
#  'carryology',
#  'federal reserve board',
#  'polfeno',
#  'IdF',
#  'perou',
#  'emba',
#  'Nos',
#  'IFCC',
#  'lightyear',
#  'gazoport',
#  'transfer',
#  'wct',
#  'svet kapitala',
#  'aberdeen citizen',
#  'deutsches zentrum fod_wnaw luft- undyp raumfahrt',
#  'PJM',
#  'dystrybucja SA',
#  'mooc',
#  'RD Action',
#  'SRWL',
#  'PTH intermark',
#  'e-dust',
#  'afrykański pomoru świn',
#  'jednostka',
#  'pollenie SA',
#  'eda',
#  'mikronatura środowisko',
#  'konwent dyrektorów rops',
#  'raviv',
#  'SRK',
#  'industi stymulator polimodalna percepcji sensoryczna',
#  'biur łącznik',
#  'big data',
#  'sonnet',
#  'zakładem ubezpieczenie społeczny - oddział w Rzeszów',
#  'World food program ONZ',
#  'centrum badawczo – rozwojowy PZL',
#  'ceapyg',
#  'nadzór wodny w brdyujściu',
#  'iwota',
#  'future City lab',
#  'mebelbos',
#  'janbud',
#  'pza loara',
#  'kombud S . a',
#  'lan',
#  'zentrum fod_wnaw kunst undyp medien Karlsruhe',
#  'trumpf [ D.1.3',
#  'middle East',
#  'neuroinformatyki',
#  'mankola school',
#  'pdtracker',
#  'unipress - extrusion',
#  'inicjatywy społeczny',
#  'humma',
#  'zakład epistemologia i kognitywistyka',
#  'rehakompleks',
#  'airnow.gov',
#  'T.E . C',
#  'FKN',
#  'SouB-ów',
#  'answer',
#  'ukraińskie forum historyków',
#  'ecodump',
#  'ster_a',
#  'służba celny',
#  'beijing huasheng Oac Technology Li_typtap',
#  'gopt',
#  'WHISM',
#  'o.pl',
#  'cyber .MIL .PL',
#  'wnożir zut',
#  'rohlig suus logistics',
#  'oddziale kardiologiczny',
#  'ProEndocrinologia',
#  'XRD',
#  'globalna sieć leanhe',
#  'daugelavicius',
#  'Warszawa centrum targowa',
#  'uniwersytet w hradec kralowe',
#  'West den haag',
#  'millenium bridge',
#  'aca',
#  'Royal rangers',
#  'ip-czd',
#  'centrum doktryn i szkolenia SZ',
#  'technical report EFSA',
#  'wiodący zespół badawczego reg-med - lab marycz’s lab',
#  'chim',
#  'brygadźie zmechanizowane',
#  'technicky univeristat vod liberci',
#  'cracovia sacra',
#  'Il',
#  'biuro planowanie przestrzenny miast',
#  'elektrowni łaziska',
#  'SLB Berlin',
#  'oma',
#  'gthina_b rad',
#  'medicine estoril',
#  'batóh_pa',
#  'spacive',
#  'sutari',
#  'ecLi',
#  'polski rynek praca',
#  'VHLGenetics',
#  'piete',
#  'de ceuster meststoffen NV',
#  'RIS-ów',
#  'ingemmet',
#  'solidarnościowy',
#  'tashkent',
#  'infrastress',
#  'biuro konstrukcyjno - wdrożeniowy',
#  'jewisho Studies',
#  'centrum badawcze ABB',
#  'Cha',
#  'zuo łódź',
#  'sulejowiecki',
#  'cały życie',
#  'ferrero',
#  'univerzita eger',
#  'wbiiś',
#  'filii swps',
#  'GFK Polonia 2019',
#  'VB clinic',
#  'pystro',
#  'potemkine films',
#  'Pot',
#  'e8tak_a',
#  'biuro hydrograficzne marynarki wojenna',
#  'liga',
#  'LINK2',
#  'hallerczyk',
#  'humanitas',
#  'aja',
#  'organization forówna social innovation „ arno',
#  'pimpo',
#  'MUB',
#  'atlasus',
#  'mika',
#  'rektor PG',
#  'mEN-',
#  'icrniczy network',
#  'ośrodek technika leśny w jarocinie',
#  'kliniką papier',
#  'krrit',
#  'kowale biznes',
#  'kognitywistyka',
#  'sgrt',
#  'schulz',
#  'agrobiotest',
#  'cnmat UC berkeley',
#  'szkole głóg gospodarstwo wiejcki',
#  'furuchi.co.jp',
#  'mouton de gruyter',
#  'telec italia ( iT',
#  'ambasadzie Kanada w Warszawa',
#  'M . fečkan',
#  'sykomi',
#  'telegraph',
#  'telewizja orion',
#  'BFK',
#  'air silesia',
#  'CIS',
#  'centrum dialogu',
#  'automatyka',
#  'kunst.off plattenbau',
#  'birkhäuser',
#  'zespół ZT UM',
#  'kancelaria wilmerhale',
#  'goed',
#  'SP 3 w kołobrzeg',
#  'dział handlowy',
#  'st_chacpa . on . święty . Wojciech w Gdańsk',
#  'global dairy platform',
#  'krakowskie chorągwi męsko',
#  'ddps',
#  'dosho',
#  'uto WSG',
#  'ŚCZP',
#  'gpz-ów',
#  'Sisage',
#  'e - Service',
#  'BWA rzeszów',
#  'helsinki commission',
#  'rozwój i wymiany',
#  'rmtechFlow',
#  'crisis management innovation network europe',
#  '16 ośrodki doradztwo rolniczy',
#  'aste summer convention',
#  'metropola górnośląsko - zagłębiowskiej',
#  'ojnie',
#  'stacja Filip',
#  'WK onomięc',
#  'zpas',
#  'gimnazjum Gdański „ niebo polski',
#  'universada dać porto',
#  '1.Tomaszów lubelski',
#  'tabor opowiadaczy',
#  'werk arena',
#  'poradnia językow UŚ',
#  'proarte mallnitz',
#  'insurtech',
#  'avicenna oil',
#  'Libri separat',
#  'centres of expertise',
#  'Narty_ja',
#  'EUco',
#  'pap.pl',
#  'greater poland',
#  'państwowego monitoring środowisko',
#  'P . P . H . " aquamar',
#  'mtu aero engines Polska Sp .',
#  'zespół wa PK',
#  'polityka',
#  'wneiz',
#  'CSK MSWiA',
#  'aplex',
#  'menavitin',
#  'bgi project Sp .',
#  'czeski cieszyn',
#  'mikopac',
#  'living lab " Geodesign inny rural poland',
#  'SPB torkret Sp . z.o.o. .',
#  'beta -bio Technology',
#  'ruch ekologiczny święty . Franciszek z asyżu',
#  'komenda główny PSP w Warszawa',
#  'transylwański klaster meblowy',
#  'dgrsz',
#  'unijna',
#  'opec Sp .',
#  'stako worthington industries',
#  'austrian graduate tracking project',
#  'górażdże cement',
#  'medr',
#  'Newsweek Polska',
#  'BSP summer field school',
#  'gminny program rewitalizacja',
#  'model eg_m',
#  'vasteras',
#  'geg panino',
#  'azota',
#  'martrow technical products dol & martrow technical innovations dol',
#  'hydroprojekt Wrocław',
#  'Polska strategia wodorowa',
#  'nanoSci',
#  'grela',
#  'meteorology',
#  'budzik dla dziecko',
#  'dog',
#  'nasz szczuczyn',
#  'innovators under 35 europe',
#  'telewizja teletronik',
#  'ce_kowam',
#  'radonowe stanowisko wzorcowe',
#  'interlab',
#  'oekotex annual report 2019/2012',
#  'rektorat',
#  'univerzita palackého olomouc',
#  'hamelin',
#  'start global',
#  'icter',
#  'ialt',
#  'uliech',
#  'ioś - PiB',
#  'agro- vetdiagnostica Sp .',
#  'bank nordea',
#  'emission control area',
#  'poland expert roundtable',
#  'polski oddziału pen Club',
#  'udsc',
#  'odeski',
#  'dolnośląskie inteligentny specjalizacje',
#  'on -PAC forte',
#  'nice',
#  'konferecji',
#  'moldova and ukraine',
#  'tub " cuprum',
#  'magazynem wirtualnym białko roślinny',
#  'host',
#  'rotary Club biały podlaski',
#  'BC ferries',
#  'komitet ds. analiz społeczno - ekonomiczny',
#  'WFAIS',
#  'siphotonic',
#  'mopier',
#  'moech Olsztyn',
#  'auli UZ',
#  'rabka festival',
#  'forschungsstand -und perspektiven',
#  'WGIK',
#  'pädagogik',
#  'EC białystok',
#  'nctrzNevad acceleration program',
#  'naczelny organizacja techniczny',
#  'school on geometry and physics',
#  'ZM wierzejki',
#  'SCID',
#  'novilet',
#  'dział tok studia',
#  'UNeP/POPSSSSS/P.8//./16/../6/d16nA/d.16/d1//1///6/',
#  'Shell',
#  'opus',
#  'odlewnie polski',
#  'nogadism',
#  'basell Orlen polyolefins',
#  'emja',
#  'historisch',
#  'bambrów',
#  'KG uktonicza',
#  'platform - artykuł',
#  'roddinglaw Road',
#  'turkey',
#  'polski obserwatorium BRD',
#  'mifir',
#  'SGDM',
#  'Polonia misterios',
#  'centrum badawczo - rozwojowe nofasome',
#  'bloch gpa',
#  'program interreg pl-sk',
#  'WFTiMS',
#  'arria',
#  'tybsp',
#  'etodal',
#  'syntra vlaanderen',
#  'zakład utylizacja odpad komunalny w hryniewicz',
#  'zespół ds. covid',
#  'seaqual',
#  'distant relatives dolar_ameryłsza',
#  'Rosja',
#  'kaminski MF',
#  'olxoraz',
#  'coal mines',
#  'EU-XFEL',
#  'Cha society switzerland',
#  'dbb1',
#  'jazz forum',
#  'resort środowisko',
#  'tekez',
#  'medinice',
#  'organ-on-a - chip',
#  'ngo’s',
#  'RRR networko',
#  'tenderness',
#  'imdik',
#  'PL-Saksonia',
#  'FRUMIS',
#  'HBM fibersensing',
#  'dyrektor ochrona środowisko w Gdańsk',
#  'ligna',
#  'Ek',
#  'MŚP bioatlantis Li_typtap .',
#  'slag om bourtange',
#  'endothelix',
#  'zał.4',
#  'cerfy',
#  'departament strategia MSZ',
#  'zakład psychologie socjalizacji i wspomaganie rozwój gam',
#  'EC Gdańsk',
#  'National cyber security centre',
#  'Bayer AG',
#  'dWa',
#  'Francja',
#  'kancelaria radcyw prawny',
#  'Australia pty Li_typtap .',
#  'Emtym_połora_dabołół systems Sp .',
#  'prodromus SA .',
#  'aglomeracja kielecka',
#  'przedstawicielstwo',
#  'performans',
#  'Robert bobch gmba',
#  'caladrius',
#  'chorągwi ZHP',
#  'eurdep',
#  'veolia',
#  'P.L . Copernicus',
#  'SGS Polska',
#  'uniwersytet przyrodniczy w Poznań',
#  'UŚ młodzież',
#  'professionals education',
#  'EFT-POS',
#  ...}
